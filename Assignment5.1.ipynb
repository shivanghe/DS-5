# %%
#import libararies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#read the data
df=pd.read_csv("50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
#EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df1=df.rename({'R&D Spend':'RDS','Administration':'ADMS','Marketing Spend':'MKTS'},axis=1)
df1
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
#check for duplicate value
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [RDS, ADMS, MKTS, State, Profit]
# Index: []

# %%
df1.describe()
# Out:
#                  RDS           ADMS           MKTS         Profit
# count      50.000000      50.000000      50.000000      50.000000
# mean    73721.615600  121344.639600  211025.097800  112012.639200
# std     45902.256482   28017.802755  122290.310726   40306.180338
# min         0.000000   51283.140000       0.000000   14681.400000
# 25%     39936.370000  103730.875000  129300.132500   90138.902500
# 50%     73051.080000  122699.795000  212716.240000  107978.190000
# 75%    101602.800000  144842.180000  299469.085000  139765.977500
# max    165349.200000  182645.560000  471784.100000  192261.830000

# %%
#Data visualization

# %%
plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=250
sns.set_style('darkgrid')

# %%
sns.pairplot(df1)

# %%
#correlation analysis
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#model building

# %%
import statsmodels.formula.api as smf

# %%
model=smf.ols("Profit~RDS+ADMS+MKTS",data=df1).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 11 Apr 2023   Prob (F-statistic):           4.53e-30
# Time:                        15:49:25   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
#simple linear regression

# %%
ADMS=smf.ols('Profit~ADMS',data=df1).fit()

ADMS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Tue, 11 Apr 2023   Prob (F-statistic):              0.162
# Time:                        15:49:31   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7.697e+04   2.53e+04      3.040      0.004    2.61e+04    1.28e+05
# ...

# %%
#Calculate VIF

# %%
df1.columns
# Out:
# Index(['RDS', 'ADMS', 'MKTS', 'State', 'Profit'], dtype='object')

# %%
rsq_r=smf.ols("RDS~ADMS+MKTS",data=df1).fit().rsquared
vif_r=1/(1-rsq_r)

rsq_a=smf.ols("ADMS~RDS+MKTS",data=df1).fit().rsquared
vif_a=1/(1-rsq_a)

rsq_m=smf.ols("MKTS~RDS+ADMS",data=df1).fit().rsquared
vif_m=1/(1-rsq_m)

# Putting the values in Dataframe format
d1={'Feature':['RDS','ADMS','MKTS'],'Vif':[vif_r,vif_a,vif_m]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Feature       Vif
# 0     RDS  2.468903
# 1    ADMS  1.175091
# 2    MKTS  2.326773

# %%
# None Feature has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %%
# model validation techniques

# %%
#1. Residual analysis

# %%
#Normality test
import statsmodels.api as sm

# %%
#Q-Q plot
sm.qqplot(model.resid,line='q');

# %%
np.where(model.resid<-30000)
# Out:
# (array([49], dtype=int64),)

# %%
#Residual plot of homoscedasticity

# %%
plt.scatter(model.fittedvalues,model.resid)
plt.xlabel('fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %%
#Residual vs Regressor

# %%
sm.graphics.plot_regress_exog(model,'RDS');
# Out:
# eval_env: 1

# %%
sm.graphics.plot_regress_exog(model,'ADMS');
# Out:
# eval_env: 1

# %%
sm.graphics.plot_regress_exog(model,'MKTS');
# Out:
# eval_env: 1

# %%
#Model deletion techniques

# %%
#Cook's distance

# %%
inf=model.get_influence()
c,p=inf.cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
#cook's distance plot

# %%
plt.stem(range(len(df1)),c)
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(c),np.max(c)
# Out:
# (49, 0.2880822927543264)

# %%
df1.iloc[[49]]
# Out:
#     RDS      ADMS      MKTS       State   Profit
# 49  0.0  116983.8  45173.06  California  14681.4

# %%
df1.head(5)
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
#calculate cutoff
k=len(df1.columns)
n=len(df1)
cut_off=3*(k+1)/n
cut_off
# Out:
# 0.36

# %%
 #influence plot
from statsmodels.graphics.regressionplots import influence_plot

influence_plot(model)
plt.axvline(cut_off,color='red')

# %%
#improving the model
df1.drop(index=[49],inplace=True)

# %%
df1
# Out:
#           RDS       ADMS       MKTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
 model=smf.ols("Profit~RDS+ADMS+MKTS",data=df1).fit()
    
inf=model.get_influence()
c,p=inf.cooks_distance

# %%
plt.stem(range(len(df1)),c)
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(c),np.max(c)
# Out:
# (48, 0.39274420556321443)

# %%
df1.drop(index=[48],inplace=True)

# %%
 model=smf.ols("Profit~RDS+ADMS+MKTS",data=df1).fit()
    
inf=model.get_influence()
c,p=inf.cooks_distance

# %%
plt.stem(range(len(df1)),c)
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(c),np.max(c)
# Out:
# (46, 0.13829133994334297)

# %%
df1.drop(index=[46],inplace=True)

# %%
model=smf.ols("Profit~RDS+ADMS+MKTS",data=df1).fit()
    
inf=model.get_influence()
c,p=inf.cooks_distance

# %%
plt.stem(range(len(df1)),c)
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(c),np.max(c)
# Out:
# (45, 0.09283373205094168)

# %%
#since the value is < 1,we can stop the diagnostic process and finalize the model

# %%
final_model=smf.ols("Profit~RDS+ADMS+MKTS",data=df1).fit()
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Tue, 11 Apr 2023   Prob (F-statistic):           8.85e-32
# Time:                        15:53:16   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.238e+04   5542.657      9.451      0.000    4.12e+04    6.35e+04
# ...

# %%
#predicting for new records

# %%
df1.head()
# Out:
#          RDS       ADMS       MKTS       State     Profit
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
newdf=pd.DataFrame({
    'RDS':[70000],
    'ADMS':[87000],
    'MKTS':[140000]
})

# %%
newdf
# Out:
#      RDS   ADMS    MKTS
# 0  70000  87000  140000

# %%
final_model.predict(newdf)
# Out:
# 0    108793.75885
# dtype: float64
